# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("dataset/movies.csv")
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors = pd.read_csv("dataset/directors.csv")
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
movies.drop(["Unnamed: 0"], axis = 1, inplace=True)
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
directors.drop(["Unnamed: 0"], axis = 1, inplace = True)
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 126.0+ KB

# %%
directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2349 entries, 0 to 2348
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   director_name  2349 non-null   object
#  1   id             2349 non-null   int64
#  2   gender         1724 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 55.2+ KB

# %%
movies.describe()
# Out:
#                  id        budget   popularity       revenue  vote_average  \
# count   1465.000000  1.465000e+03  1465.000000  1.465000e+03   1465.000000
# mean   45225.191126  4.802295e+07    30.855973  1.432539e+08      6.368191
# std     1189.096396  4.935541e+07    34.845214  2.064918e+08      0.818033
# min    43597.000000  0.000000e+00     0.000000  0.000000e+00      3.000000
# 25%    44236.000000  1.400000e+07    11.000000  1.738013e+07      5.900000
# 50%    45022.000000  3.300000e+07    23.000000  7.578164e+07      6.400000
# 75%    45990.000000  6.600000e+07    41.000000  1.792469e+08      6.900000
# max    48395.000000  3.800000e+08   724.000000  2.787965e+09      8.300000
#
#          vote_count  director_id         year
# count   1465.000000  1465.000000  1465.000000
# mean    1146.396587  5040.192491  2002.615017
# std     1578.077438   258.059631     8.680141
# min        1.000000  4762.000000  1976.000000
# 25%      216.000000  4845.000000  1998.000000
# ...

# %%
movies.describe(include = object)
# Out:
#          title month     day
# count     1465  1465    1465
# unique    1465    12       7
# top     Avatar   Dec  Friday
# freq         1   193     654

# %%
directors.describe(include = object)
# Out:
#         director_name gender
# count            2349   1724
# unique           2349      2
# top     James Cameron   Male
# freq                1   1574

# %%
movies.nunique()
# Out:
# id              1465
# budget           201
# popularity       128
# revenue         1267
# title           1465
# vote_average      51
# vote_count      1019
# director_id      199
# year              41
# month             12
# day                7
# dtype: int64

# %%
directors.nunique()
# Out:
# director_name    2349
# id               2349
# gender              2
# dtype: int64

# %%
# Merging 2 dataset
data = movies.merge(directors, left_on = "director_id", right_on = 'id', how = "left")
new_data = data
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_x           1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   director_id    1465 non-null   int64
#  8   year           1465 non-null   int64
#  9   month          1465 non-null   object
#  10  day            1465 non-null   object
#  11  director_name  1465 non-null   object
#  12  id_y           1465 non-null   int64
#  13  gender         1341 non-null   object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 171.7+ KB

# %%
data.drop(["id_x", "id_y", "director_id"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#       budget  popularity     revenue  \
# 0  237000000         150  2787965087
# 1  300000000         139   961000000
# 2  245000000         107   880674609
# 3  250000000         112  1084939099
# 4  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data.tail()
# Out:
#       budget  popularity  revenue           title  vote_average  vote_count  \
# 1460       0           3   321952  The Last Waltz           7.9          64
# 1461   27000          19  3151130          Clerks           7.4         755
# 1462       0           7        0         Rampage           6.0         131
# 1463       0           3        0         Slacker           6.4          77
# 1464  220000          14  2040920     El Mariachi           6.6         238
#
#       year month      day      director_name gender
# 1460  1978   May   Monday    Martin Scorsese   Male
# 1461  1994   Sep  Tuesday        Kevin Smith   Male
# 1462  2009   Aug   Friday           Uwe Boll   Male
# 1463  1990   Jul   Friday  Richard Linklater   Male
# 1464  1992   Sep   Friday   Robert Rodriguez    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1465 entries, 0 to 1464
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   budget         1465 non-null   int64
#  1   popularity     1465 non-null   int64
#  2   revenue        1465 non-null   int64
#  3   title          1465 non-null   object
#  4   vote_average   1465 non-null   float64
#  5   vote_count     1465 non-null   int64
#  6   year           1465 non-null   int64
#  7   month          1465 non-null   object
#  8   day            1465 non-null   object
#  9   director_name  1465 non-null   object
#  10  gender         1341 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 137.3+ KB

# %%
movies["director_id"].isin(directors["id"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
data.describe()
# Out:
#              budget   popularity       revenue  vote_average    vote_count  \
# count  1.465000e+03  1465.000000  1.465000e+03   1465.000000   1465.000000
# mean   4.802295e+07    30.855973  1.432539e+08      6.368191   1146.396587
# std    4.935541e+07    34.845214  2.064918e+08      0.818033   1578.077438
# min    0.000000e+00     0.000000  0.000000e+00      3.000000      1.000000
# 25%    1.400000e+07    11.000000  1.738013e+07      5.900000    216.000000
# 50%    3.300000e+07    23.000000  7.578164e+07      6.400000    571.000000
# 75%    6.600000e+07    41.000000  1.792469e+08      6.900000   1387.000000
# max    3.800000e+08   724.000000  2.787965e+09      8.300000  13752.000000
#
#               year
# count  1465.000000
# mean   2002.615017
# std       8.680141
# min    1976.000000
# 25%    1998.000000
# 50%    2004.000000
# 75%    2009.000000
# max    2016.000000

# %%
data.describe(include = object)
# Out:
#          title month     day     director_name gender
# count     1465  1465    1465              1465   1341
# unique    1465    12       7               199      2
# top     Avatar   Dec  Friday  Steven Spielberg   Male
# freq         1   193     654                26   1309

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
data["revenue"] = data["revenue"] / 1000000 # Revenue in Million dollor

# %%
data.head()
# Out:
#       budget  popularity      revenue  \
# 0  237000000         150  2787.965087
# 1  300000000         139   961.000000
# 2  245000000         107   880.674609
# 3  250000000         112  1084.939099
# 4  258000000         115   890.871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
data["budget"] = data["budget"] / 1000000 # Budget in Million dollor

# %%
data.head()
# Out:
#    budget  popularity      revenue                                     title  \
# 0   237.0         150  2787.965087                                    Avatar
# 1   300.0         139   961.000000  Pirates of the Caribbean: At World's End
# 2   245.0         107   880.674609                                   Spectre
# 3   250.0         112  1084.939099                     The Dark Knight Rises
# 4   258.0         115   890.871626                              Spider-Man 3
#
#    vote_average  vote_count  year month       day      director_name gender
# 0           7.2       11800  2009   Dec  Thursday      James Cameron   Male
# 1           6.9        4500  2007   May  Saturday     Gore Verbinski   Male
# 2           6.3        4466  2015   Oct    Monday         Sam Mendes   Male
# 3           7.6        9106  2012   Jul    Monday  Christopher Nolan   Male
# 4           5.9        3576  2007   May   Tuesday          Sam Raimi   Male

# %%
# Querying the dataframe

data["vote_average"] >= 7
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460     True
# 1461     True
# 1462    False
# 1463    False
# 1464    False
# Name: vote_average, Length: 1465, dtype: bool

# %%
data.loc[data["vote_average"] >= 7, : ]

# data[data["vote_average"] >= 7] # not recommened
# syntax not making clear whether it is using explcity or implcity infices
# Out:
#        budget  popularity      revenue  \
# 0     237.000         150  2787.965087
# 3     250.000         112  1084.939099
# 8     200.000         145  1065.659812
# 14    250.000         120   956.019788
# 16    250.000          94   958.400000
# ...       ...         ...          ...
# 1456    0.010          20     7.000000
# 1457    0.000           5     0.000000
# 1458    0.060          27     3.221152
# 1460    0.000           3     0.321952
# 1461    0.027          19     3.151130
#
#                                            title  vote_average  vote_count  \
# 0                                         Avatar           7.2       11800
# 3                          The Dark Knight Rises           7.6        9106
# 8     Pirates of the Caribbean: Dead Man's Chest           7.0        5246
# 14     The Hobbit: The Battle of the Five Armies           7.1        4760
# 16           The Hobbit: The Desolation of Smaug           7.6        4524
# ...

# %%
data.loc[data["vote_average"] >= 7, ["title", "director_name"]]
# Out:
#                                            title      director_name
# 0                                         Avatar      James Cameron
# 3                          The Dark Knight Rises  Christopher Nolan
# 8     Pirates of the Caribbean: Dead Man's Chest     Gore Verbinski
# 14     The Hobbit: The Battle of the Five Armies      Peter Jackson
# 16           The Hobbit: The Desolation of Smaug      Peter Jackson
# ...                                          ...                ...
# 1456                                  Eraserhead        David Lynch
# 1457                                  The Mighty      Peter Chelsom
# 1458                                          Pi   Darren Aronofsky
# 1460                              The Last Waltz    Martin Scorsese
# 1461                                      Clerks        Kevin Smith
#
# [363 rows x 2 columns]

# %%
# give title and director name for highly rated movies which were released in or after 2015
data.loc[(data["vote_average"]>=7) & (data["year"] >= 2015), ["title", "director_name"]]
# Out:
#                                           title                director_name
# 30                                    Furious 7                    James Wan
# 78                           Mad Max: Fury Road                George Miller
# 106                                The Revenant  Alejandro González Iñárritu
# 162                                 The Martian                 Ridley Scott
# 312                     The Man from U.N.C.L.E.                  Guy Ritchie
# 394                           The Hateful Eight            Quentin Tarantino
# 519   13 Hours: The Secret Soldiers of Benghazi                  Michael Bay
# 617                             The Conjuring 2                    James Wan
# 625                                  The Intern                 Nancy Meyers
# 635                             Bridge of Spies             Steven Spielberg
# 808                                    Southpaw                Antoine Fuqua
# ...

# %%
# Find me rows corresponding top 5 popular movies

data.sort_values(["popularity"], ascending = False).head(5)
# Out:
#      budget  popularity      revenue  \
# 58    165.0         724   675.120017
# 78    150.0         434   378.858340
# 119   140.0         271   655.011224
# 120   125.0         206   752.100229
# 45    185.0         187  1004.558444
#
#                                                  title  vote_average  \
# 58                                        Interstellar           8.1
# 78                                  Mad Max: Fury Road           7.2
# 119  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 120              The Hunger Games: Mockingjay - Part 1           6.6
# 45                                     The Dark Knight           8.2
#
#      vote_count  year month        day      director_name gender
# 58        10867  2014   Nov  Wednesday  Christopher Nolan   Male
# 78         9427  2015   May  Wednesday      George Miller   Male
# 119        6985  2003   Jul  Wednesday     Gore Verbinski   Male
# ...

# %%
# title for all the movies directed by "Christopher Nolan"

data.loc[data["director_name"] == "Steven Spielberg", ["title"]].head(5)
# Out:
#                                                  title
# 37   Indiana Jones and the Kingdom of the Crystal S...
# 105                                            The BFG
# 110                                  War of the Worlds
# 114                           The Adventures of Tintin
# 166                                    Minority Report

# %%
# apply
# gender --> Male, Female (0, 1)
# ML Algos want all the features to be numerical

def encode(gender):
    if gender == "Male":
        return 0
    elif gender == "Female":
        return 1
    else:
        return gender

# %%
data["gender"] = data["gender"].apply(encode)
data
# Out:
#        budget  popularity      revenue  \
# 0     237.000         150  2787.965087
# 1     300.000         139   961.000000
# 2     245.000         107   880.674609
# 3     250.000         112  1084.939099
# 4     258.000         115   890.871626
# ...       ...         ...          ...
# 1460    0.000           3     0.321952
# 1461    0.027          19     3.151130
# 1462    0.000           7     0.000000
# 1463    0.000           3     0.000000
# 1464    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
data["sum"] = data[["revenue", "budget"]].apply(np.sum, axis = 1)

# %%
data.head()
# Out:
#    budget  popularity      revenue                                     title  \
# 0   237.0         150  2787.965087                                    Avatar
# 1   300.0         139   961.000000  Pirates of the Caribbean: At World's End
# 2   245.0         107   880.674609                                   Spectre
# 3   250.0         112  1084.939099                     The Dark Knight Rises
# 4   258.0         115   890.871626                              Spider-Man 3
#
#    vote_average  vote_count  year month       day      director_name  gender  \
# 0           7.2       11800  2009   Dec  Thursday      James Cameron     0.0
# 1           6.9        4500  2007   May  Saturday     Gore Verbinski     0.0
# 2           6.3        4466  2015   Oct    Monday         Sam Mendes     0.0
# 3           7.6        9106  2012   Jul    Monday  Christopher Nolan     0.0
# 4           5.9        3576  2007   May   Tuesday          Sam Raimi     0.0
#
#            sum
# 0  3024.965087
# ...

# %%
data["profit"] = data[["budget", "revenue"]].apply(np.diff, axis = 1)
data.head()
# Out:
#    budget  popularity      revenue                                     title  \
# 0   237.0         150  2787.965087                                    Avatar
# 1   300.0         139   961.000000  Pirates of the Caribbean: At World's End
# 2   245.0         107   880.674609                                   Spectre
# 3   250.0         112  1084.939099                     The Dark Knight Rises
# 4   258.0         115   890.871626                              Spider-Man 3
#
#    vote_average  vote_count  year month       day      director_name  gender  \
# 0           7.2       11800  2009   Dec  Thursday      James Cameron     0.0
# 1           6.9        4500  2007   May  Saturday     Gore Verbinski     0.0
# 2           6.3        4466  2015   Oct    Monday         Sam Mendes     0.0
# 3           7.6        9106  2012   Jul    Monday  Christopher Nolan     0.0
# 4           5.9        3576  2007   May   Tuesday          Sam Raimi     0.0
#
#            sum               profit
# ...

# %%
def calProfit(x): 
    return x["revenue"] - x["budget"]

# %%
data["profit"] = data.apply(calProfit, axis = 1)
data.head()
# Out:
#    budget  popularity      revenue                                     title  \
# 0   237.0         150  2787.965087                                    Avatar
# 1   300.0         139   961.000000  Pirates of the Caribbean: At World's End
# 2   245.0         107   880.674609                                   Spectre
# 3   250.0         112  1084.939099                     The Dark Knight Rises
# 4   258.0         115   890.871626                              Spider-Man 3
#
#    vote_average  vote_count  year month       day      director_name  gender  \
# 0           7.2       11800  2009   Dec  Thursday      James Cameron     0.0
# 1           6.9        4500  2007   May  Saturday     Gore Verbinski     0.0
# 2           6.3        4466  2015   Oct    Monday         Sam Mendes     0.0
# 3           7.6        9106  2012   Jul    Monday  Christopher Nolan     0.0
# 4           5.9        3576  2007   May   Tuesday          Sam Raimi     0.0
#
# ...

# %% [markdown]
# ## Grouping

# %%
new_data
# Out:
#        budget  popularity      revenue  \
# 0     237.000         150  2787.965087
# 1     300.000         139   961.000000
# 2     245.000         107   880.674609
# 3     250.000         112  1084.939099
# 4     258.000         115   890.871626
# ...       ...         ...          ...
# 1460    0.000           3     0.321952
# 1461    0.027          19     3.151130
# 1462    0.000           7     0.000000
# 1463    0.000           3     0.000000
# 1464    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %%
new_data = movies.merge(directors, left_on = "director_id", right_on = 'id', how = "left")
new_data.drop(["id_x", "id_y", "director_id"], inplace = True, axis = 1)

# %%
new_data
# Out:
#          budget  popularity     revenue  \
# 0     237000000         150  2787965087
# 1     300000000         139   961000000
# 2     245000000         107   880674609
# 3     250000000         112  1084939099
# 4     258000000         115   890871626
# ...         ...         ...         ...
# 1460          0           3      321952
# 1461      27000          19     3151130
# 1462          0           7           0
# 1463          0           3           0
# 1464     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# ### How can we know the number of movies released by a particular director, say, Christopher Nolan?

# %%
new_data.loc[new_data["director_name"] == "Christopher Nolan", "title"].count()
# Out:
# 8

# %% [markdown]
# ### No. of Movies of all directors

# %%
new_data["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %% [markdown]
# ## Group based Aggregates

# %%
new_data.groupby(["director_name"])

# %%
new_data.groupby(["director_name"]).ngroups
# Out:
# 199

# %%
new_data.groupby(["director_name"]).groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
new_data.groupby(["director_name"]).get_group('Steven Spielberg')
# Out:
#          budget  popularity    revenue  \
# 37    185000000          75  786636033
# 105   140000000          44  183345589
# 110   132000000          48  591739379
# 114   130000000          89  371940071
# 166   102000000          65  358372926
# 219   100000000          34  235926552
# 296    73000000           2  229074524
# 304    60000000          57  219417255
# 309    70000000          29  130358911
# 333    70000000          33  300854823
# 342    66000000          29  177584879
# 360    70000000          76  481840909
# 363    65000000          36  275293450
# 390    63000000          40  920100000
# 495    52000000          73  352114312
# 552    48000000          80  474171806
# 635    40000000          48  165478348
# 647    36000000           3   74000000
# 766    35000000          10   31755742
# 834    28000000          66  333000000
# 901    22000000         104  321365567
# 995    18000000          68  389925971
# 997    20000000          52  303788635
# ...

# %%
new_data.groupby(["director_name"])["title"].count()
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %% [markdown]
# ### How can we find multiple aggregations of any feature?

# %%
new_data.groupby(["director_name"])["year"].aggregate(['min', 'max'])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %% [markdown]
# ## Group based Filtering

# %% [markdown]
# ### How we find details of the movies by high budget directors?
# #### Lets assume,
#
# - high budget director -> any director with atleast one movie with budget >100M

# %%
data_dir_budget = new_data.groupby("director_name")["budget"].max().reset_index()
data_dir_budget
# Out:
#                    director_name     budget
# 0                     Adam McKay  100000000
# 1                  Adam Shankman   80000000
# 2    Alejandro González Iñárritu  135000000
# 3                    Alex Proyas  140000000
# 4                Alexander Payne   30000000
# ..                           ...        ...
# 194                   Wes Craven   40000000
# 195            Wolfgang Petersen  175000000
# 196                  Woody Allen   30000000
# 197                  Zack Snyder  250000000
# 198                  Zhang Yimou   94000000
#
# [199 rows x 2 columns]

# %%
names = data_dir_budget.loc[data_dir_budget["budget"] >= 100, "director_name"]
names
# Out:
# 0                       Adam McKay
# 1                    Adam Shankman
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 4                  Alexander Payne
#                   ...
# 194                     Wes Craven
# 195              Wolfgang Petersen
# 196                    Woody Allen
# 197                    Zack Snyder
# 198                    Zhang Yimou
# Name: director_name, Length: 199, dtype: object

# %%
data.loc[data["director_name"].isin(names)]
# Out:
#        budget  popularity      revenue  \
# 0     237.000         150  2787.965087
# 1     300.000         139   961.000000
# 2     245.000         107   880.674609
# 3     250.000         112  1084.939099
# 4     258.000         115   890.871626
# ...       ...         ...          ...
# 1460    0.000           3     0.321952
# 1461    0.027          19     3.151130
# 1462    0.000           7     0.000000
# 1463    0.000           3     0.000000
# 1464    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# #### Can we do filtering of groups in a single go?
#
# **YES**

# %%
new_data.groupby("director_name").filter(lambda x: x["budget"].max() >= 100)
# Out:
#          budget  popularity     revenue  \
# 0     237000000         150  2787965087
# 1     300000000         139   961000000
# 2     245000000         107   880674609
# 3     250000000         112  1084939099
# 4     258000000         115   890871626
# ...         ...         ...         ...
# 1460          0           3      321952
# 1461      27000          19     3151130
# 1462          0           7           0
# 1463          0           3           0
# 1464     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# Notice what's happening here?
# - We first group data by director and then use `groupby().filter` function
# - **Groups are filtered if they do not satisfy the boolean criterion** specified by function
# - This is called  **Group Based Filtering**

# %% [markdown]
# **NOTE**
#
# We are filtering the **groups** here and **not the rows**
#
# ==> The result is **not a groupby object** but **regular pandas DataFrame** with the **filtered groups eliminated**

# %% [markdown]
# ## Group Based Apply

# %% [markdown]
# Now let's assume, we call a movi risky if,
# - its budget is higher than the average revenue of its director
#
# #### How do we filter risky movies?
#
# We can subtract the average `revenue` of a director from `budget` col, for each director
#
# #### Can we use `apply` here?
#
# Yes!
#
# #### How do we use apply for this column?
#
# - We will define a function to compute the subtraction
# - Pass this function in `apply`

# %%
def func(x):
    x["risky"] = x["budget"] - x["revenue"].mean() >= 0
    return x
data_risky = new_data.groupby("director_name").apply(func)
data_risky
# Out:
#          budget  popularity     revenue  \
# 0     237000000         150  2787965087
# 1     300000000         139   961000000
# 2     245000000         107   880674609
# 3     250000000         112  1084939099
# 4     258000000         115   890871626
# ...         ...         ...         ...
# 1460          0           3      321952
# 1461      27000          19     3151130
# 1462          0           7           0
# 1463          0           3           0
# 1464     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...

# %% [markdown]
# Recall `apply()` from our earlier lectures
#
# What did we do here?
#
# - Defined a custom function
# - Grouped data acc to `director_name`
# - Subtracted mean of `budget` from `revenue`
# - Used apply with the custom function on the grouped data

# %%
data_risky.loc[data_risky[""]]
