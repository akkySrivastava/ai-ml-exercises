# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
  "Accessories": ["Laptop", "Laptop", "Ipad", "Ipad", "Tablet", "Laptop"],
  "customer": ["Andrew", "Andrew", "Tom", "Andrew", "Tobey", "Peter"],
  "quantity": [1, 2, 2, 3, 1, 2],
})

df
# Out:
#   Accessories customer  quantity
# 0      Laptop   Andrew         1
# 1      Laptop   Andrew         2
# 2        Ipad      Tom         2
# 3        Ipad   Andrew         3
# 4      Tablet    Tobey         1
# 5      Laptop    Peter         2

# %%
df.groupby(["Accessories", "customer"])["quantity"].sum()
# Out:
# Accessories  customer
# Ipad         Andrew      3
#              Tom         2
# Laptop       Andrew      3
#              Peter       2
# Tablet       Tobey       1
# Name: quantity, dtype: int64

# %%
df.pivot(index="Accessories", columns="customer", values="quantity")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df.pivot(index="Accessories", columns="customer", values="quantity")
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:7882, in DataFrame.pivot(self, index, columns, values)
#    7877 @Substitution("")
#    7878 @Appender(_shared_docs["pivot"])
#    7879 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7880     from pandas.core.reshape.pivot import pivot
# -> 7882     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# File ~\miniconda3\lib\site-packages\pandas\core\series.py:4157, in Series.unstack(self, level, fill_value)
#    4114 """
#    4115 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4116
#    (...)
#    4153 b    2    4
#    4154 """
#    4155 from pandas.core.reshape.reshape import unstack
# -> 4157 return unstack(self, level, fill_value)
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\reshape.py:491, in unstack(obj, level, fill_value)
#     489 if is_1d_only_ea_dtype(obj.dtype):
#     490     return _unstack_extension_series(obj, level, fill_value)
# --> 491 unstacker = _Unstacker(
#     492     obj.index, level=level, constructor=obj._constructor_expanddim
#     493 )
#     494 return unstacker.get_result(
#     495     obj._values, value_columns=None, fill_value=fill_value
#     496 )
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\reshape.py:140, in _Unstacker.__init__(self, index, level, constructor)
#     133 if num_cells > np.iinfo(np.int32).max:
#     134     warnings.warn(
#     135         f"The following operation may generate {num_cells} cells "
#     136         f"in the resulting pandas object.",
#     137         PerformanceWarning,
#     138     )
# --> 140 self._make_selectors()
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\reshape.py:192, in _Unstacker._make_selectors(self)
#     189 mask.put(selector, True)
#     191 if mask.sum() < len(self.index):
# --> 192     raise ValueError("Index contains duplicate entries, cannot reshape")
#     194 self.group_index = comp_index
#     195 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
df.set_index(["Accessories", "customer"])["quantity"]
# Out:
# Accessories  customer
# Laptop       Andrew      1
#              Andrew      2
# Ipad         Tom         2
#              Andrew      3
# Tablet       Tobey       1
# Laptop       Peter       2
# Name: quantity, dtype: int64

# %% [markdown]
# ## Problem Statement
#
# - Given the data frame df as input, do the following steps for preprocessing:
#
# 1. Remove the row if all the columns have missing values.
#
# 2. Replace the missing values of "Roll_ID" column with 0 and "Name" column with "Anonymous"
#
# 3. Replace the missing values in "Marks" column with the median value of the column
#
# 4. Change the numerical columns (Roll_ID and Marks) to int datatype in the output
#
# `Note: Input data frame df has every column of an object type`

# %%
data = pd.DataFrame({
                        "Roll_ID": [412, np.nan, 456, np.nan, 434, 429, 418], 
                        "Name": ["John", "Mitra", "Ritz", np.nan, "Anny", "Hema", np.nan], 
                        "Marks": [np.nan, 32, 25, np.nan, 35, 28, 38]
                })

test = data
data
# Out:
#    Roll_ID   Name  Marks
# 0    412.0   John    NaN
# 1      NaN  Mitra   32.0
# 2    456.0   Ritz   25.0
# 3      NaN    NaN    NaN
# 4    434.0   Anny   35.0
# 5    429.0   Hema   28.0
# 6    418.0    NaN   38.0

# %%
data.dropna(how = "all", inplace = True)
data
# Out:
#    Roll_ID   Name  Marks
# 0    412.0   John    NaN
# 1      NaN  Mitra   32.0
# 2    456.0   Ritz   25.0
# 4    434.0   Anny   35.0
# 5    429.0   Hema   28.0
# 6    418.0    NaN   38.0

# %%
data.fillna(value = {"Roll_ID": 0, "Name": "Anonymous"}, inplace = True)
data
# Out:
#    Roll_ID       Name  Marks
# 0    412.0       John    NaN
# 1      0.0      Mitra   32.0
# 2    456.0       Ritz   25.0
# 4    434.0       Anny   35.0
# 5    429.0       Hema   28.0
# 6    418.0  Anonymous   38.0

# %%
data["Marks"].fillna(data["Marks"].median(), inplace = True)
data
# Out:
#    Roll_ID       Name  Marks
# 0    412.0       John   32.0
# 1      0.0      Mitra   32.0
# 2    456.0       Ritz   25.0
# 4    434.0       Anny   35.0
# 5    429.0       Hema   28.0
# 6    418.0  Anonymous   38.0

# %%
data = data.astype({"Roll_ID": "int", "Marks": "int"})

# %%
data
# Out:
#    Roll_ID       Name  Marks
# 0      412       John     32
# 1        0      Mitra     32
# 2      456       Ritz     25
# 4      434       Anny     35
# 5      429       Hema     28
# 6      418  Anonymous     38

# %%
test
# Out:
#    Roll_ID       Name  Marks
# 0    412.0       John   32.0
# 1      0.0      Mitra   32.0
# 2    456.0       Ritz   25.0
# 4    434.0       Anny   35.0
# 5    429.0       Hema   28.0
# 6    418.0  Anonymous   38.0

# %%
test.isna().sum()
# Out:
# Roll_ID    0
# Name       0
# Marks      0
# dtype: int64

# %%
test["Roll_ID"].isna().sum()
# Out:
# 0

# %%
test.isna().sum().sum()
# Out:
# 0

# %%
test.loc[[3]].isna().sum().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 test.loc[[3]].isna().sum().sum()
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([3], dtype='int64')] are in the [index]"

# %%
def fun(test):
    return test.fillna(1, inplace = True)

fun(test)

# %%
test
# Out:
#    Roll_ID       Name  Marks
# 0    412.0       John   32.0
# 1      0.0      Mitra   32.0
# 2    456.0       Ritz   25.0
# 4    434.0       Anny   35.0
# 5    429.0       Hema   28.0
# 6    418.0  Anonymous   38.0

# %%
test.loc[test["Name"].str.contains('n', na = False)].shape[0]
# Out:
# 3

# %%
test["Name"].str.contains('n', na = False)
# Out:
# 0     True
# 1    False
# 2    False
# 4     True
# 5    False
# 6     True
# Name: Name, dtype: bool

# %%
str = pd.DataFrame({'access_id': {0: 'ORG6684',   1: '4564',   2: 'ORG6995',   3: '2130',   4: '5839',   5: 'ORG1281',   6: 'ORG2651',   7: 'ORG9870',   8: 'ORG4089',   9: 'ORG3794'}})

str
# Out:
#   access_id
# 0   ORG6684
# 1      4564
# 2   ORG6995
# 3      2130
# 4      5839
# 5   ORG1281
# 6   ORG2651
# 7   ORG9870
# 8   ORG4089
# 9   ORG3794

# %%
valid_id_mask = str["access_id"].str.startswith("ORG").count()
valid_id_mask
# Out:
# 10

# %%
str.loc[valid_id_mask].access_id.count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 str.loc[valid_id_mask].access_id.count()
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 10

# %%
str.shape[0]
# Out:
# 10

# %%
stu = pd.DataFrame({'Date':["2015-12-06", "2011-12-27", "2015-09-07", "2012-12-21", "2020-02-13", "2015-06-09"], 'RID':[498, 721, 375, 464, 813, 853], 'Phy':[22, 45, 1, 65, 22, 17], 'Chem':[52, 56, 32, 50, 24, 61], 'Math':[63, 37, 68, 62, 43 ,42]})
stu
# Out:
#          Date  RID  Phy  Chem  Math
# 0  2015-12-06  498   22    52    63
# 1  2011-12-27  721   45    56    37
# 2  2015-09-07  375    1    32    68
# 3  2012-12-21  464   65    50    62
# 4  2020-02-13  813   22    24    43
# 5  2015-06-09  853   17    61    42

# %%
stu
# Out:
#          Date  RID  Phy  Chem  Math
# 0  2015-12-06  498   22    52    63
# 1  2011-12-27  721   45    56    37
# 2  2015-09-07  375    1    32    68
# 3  2012-12-21  464   65    50    62
# 4  2020-02-13  813   22    24    43
# 5  2015-06-09  853   17    61    42

# %%
stu["Date"] = pd.to_datetime(stu["Date"])

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6 non-null      datetime64[ns]
#  1   RID     6 non-null      int64
#  2   Phy     6 non-null      int64
#  3   Chem    6 non-null      int64
#  4   Math    6 non-null      int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 368.0 bytes

# %%
stu["Date"] = stu["Date"].dt.month_name()

# %%
stu
# Out:
#         Date  RID  Phy  Chem  Math
# 0   December  498   22    52    63
# 1   December  721   45    56    37
# 2  September  375    1    32    68
# 3   December  464   65    50    62
# 4   February  813   22    24    43
# 5       June  853   17    61    42

# %%
stu["Date"].value_counts().sort_index()
# Out:
# December     3
# February     1
# June         1
# September    1
# Name: Date, dtype: int64

# %%
high_freq = stu["Date"].value_counts().values[0]
high_freq
# Out:
# 3

# %%
month = stu["Date"].value_counts().index[0]

# %%
month
# Out:
# 'December'

# %%
df_new = pd.DataFrame({"City\tState": ["Kolkata\tWestBengal", "Chennai\tTamil Nadu", "Hyderabad\tTelangana", "Banglore\tKarnataka"]})
df_new
# Out:
#             City\tState
# 0   Kolkata\tWestBengal
# 1   Chennai\tTamil Nadu
# 2  Hyderabad\tTelangana
# 3   Banglore\tKarnataka

# %%
df_new_split = df_new["City\tState"].str.split("\t", expand = True)
df_new_split.values
# Out:
# array([['Kolkata', 'WestBengal'],
#        ['Chennai', 'Tamil Nadu'],
#        ['Hyderabad', 'Telangana'],
#        ['Banglore', 'Karnataka']], dtype=object)

# %%
# df_new_split.columns = df_new.columns[0].split("/t")
df_new_split = pd.DataFrame(df_new_split.values, columns = df_new.columns[0].split('\t'))
df_new_split
# Out:
#         City       State
# 0    Kolkata  WestBengal
# 1    Chennai  Tamil Nadu
# 2  Hyderabad   Telangana
# 3   Banglore   Karnataka

# %%
df_new["city"], df_new["State"] = df_new.columns[0].split('/t')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 df_new["city"], df_new["State"] = df_new.columns[0].split('/t')
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
df_new
# Out:
#             City\tState
# 0   Kolkata\tWestBengal
# 1   Chennai\tTamil Nadu
# 2  Hyderabad\tTelangana
# 3   Banglore\tKarnataka

# %%
a, b, c = ["a", "b", "c"]

# %%
a
# Out:
# 'a'

# %%
b
# Out:
# 'b'

# %%
sales = pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/717/original/sales_dataset.csv?1651728217")

sales.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
sales["StockCode"].nunique()
# Out:
# 5305

# %%
most_selling = sales["Description"].unique()
most_selling
# Out:
# array(['15CM CHRISTMAS GLASS BALL 20 LIGHTS', 'PINK CHERRY LIGHTS',
#        ' WHITE CHERRY LIGHTS', ..., 'mixed up',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
sales.groupby(["Description"])["Quantity"].sum().sort_values()
# Out:
# Description
# ?                                     -26757
# given away                            -20000
# printing smudges/thrown away          -19200
# missing                               -16467
# Unsaleable, destroyed.                -15644
#                                        ...
# BROCADE RING PURSE                     70700
# JUMBO BAG RED RETROSPOT                78090
# ASSORTED COLOUR BIRD ORNAMENT          81306
# WHITE HANGING HEART T-LIGHT HOLDER     93050
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545
# Name: Quantity, Length: 5698, dtype: int64

# %%
sales.sort_values(["Quantity"], ascending = False)
# Out:
#          Invoice StockCode                         Description  Quantity  \
# 1065882   581483     23843         PAPER CRAFT , LITTLE BIRDIE     80995
# 587080    541431     23166      MEDIUM CERAMIC TOP STORAGE JAR     74215
# 90857     497946     37410  BLACK AND WHITE PAISLEY FLOWER MUG     19152
# 127168    501534     21091         SET/6 WOODLAND PAPER PLATES     12960
# 127166    501534     21099         SET/6 STRAWBERRY PAPER CUPS     12960
# ...          ...       ...                                 ...       ...
# 303996    519017     22759                                 NaN     -9600
# 750991    556691     23005        printing smudges/thrown away     -9600
# 750990    556690     23005        printing smudges/thrown away     -9600
# 587085   C541433     23166      MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 1065883  C581484     23843         PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                  InvoiceDate  Price  Customer ID         Country
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom
# 587080   2011-01-18 10:01:00   1.04      12346.0  United Kingdom
# 90857    2010-02-15 11:57:00   0.10      13902.0         Denmark
# 127168   2010-03-17 13:09:00   0.10      13902.0         Denmark
# 127166   2010-03-17 13:09:00   0.10      13902.0         Denmark
# ...                      ...    ...          ...             ...
# 303996   2010-08-13 09:14:00   0.00          NaN  United Kingdom
# 750991   2011-06-14 10:37:00   0.00          NaN  United Kingdom
# 750990   2011-06-14 10:37:00   0.00          NaN  United Kingdom
# 587085   2011-01-18 10:17:00   1.04      12346.0  United Kingdom
# 1065883  2011-12-09 09:27:00   2.08      16446.0  United Kingdom
#
# [1067371 rows x 8 columns]

# %%
date = pd.to_datetime(sales["InvoiceDate"]).dt.date

# %%
pd.to_datetime(sales["InvoiceDate"]).dt.date
# Out:
# 0          2009-12-01
# 1          2009-12-01
# 2          2009-12-01
# 3          2009-12-01
# 4          2009-12-01
#               ...
# 1067366    2011-12-09
# 1067367    2011-12-09
# 1067368    2011-12-09
# 1067369    2011-12-09
# 1067370    2011-12-09
# Name: InvoiceDate, Length: 1067371, dtype: object

# %%
sales["Quantity"].dtype
# Out:
# dtype('int64')

# %%
new_sale = sales
new_sale
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2        2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3        2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4        2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                      ...    ...          ...             ...
# 1067366  2011-12-09 12:50:00   2.10      12680.0          France
# 1067367  2011-12-09 12:50:00   4.15      12680.0          France
# 1067368  2011-12-09 12:50:00   4.15      12680.0          France
# 1067369  2011-12-09 12:50:00   4.95      12680.0          France
# 1067370  2011-12-09 12:50:00  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %%
new_sale["InvoiceDate"] = pd.to_datetime(sales["InvoiceDate"]).dt.date

# %%
new_sale
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#         InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01   6.95      13085.0  United Kingdom
# 1        2009-12-01   6.75      13085.0  United Kingdom
# 2        2009-12-01   6.75      13085.0  United Kingdom
# 3        2009-12-01   2.10      13085.0  United Kingdom
# 4        2009-12-01   1.25      13085.0  United Kingdom
# ...             ...    ...          ...             ...
# 1067366  2011-12-09   2.10      12680.0          France
# 1067367  2011-12-09   4.15      12680.0          France
# 1067368  2011-12-09   4.15      12680.0          France
# 1067369  2011-12-09   4.95      12680.0          France
# 1067370  2011-12-09  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %%
# new_sale.loc[new_sale["Description"] == "JUMBO BAG OWLS	"]
# mask = new_sale["InvoiceDate"] == "2011-12-09"
# mask.any(axis = 0)
new_sale["InvoiceDate"].apply(lambda x: x == "2009-12-01")
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1067366    False
# 1067367    False
# 1067368    False
# 1067369    False
# 1067370    False
# Name: InvoiceDate, Length: 1067371, dtype: bool

# %%
new_sale.tail(100)
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067271  581579     20713                   JUMBO BAG OWLS        10
# 1067272  581579     21931           JUMBO STORAGE BAG SUKI        10
# 1067273  581579     23199                 JUMBO BAG APPLES        30
# 1067274  581579     23353   6 GIFT TAGS VINTAGE CHRISTMAS         12
# 1067275  581579     23350          ROLL WRAP VINTAGE SPOT         25
# ...         ...       ...                              ...       ...
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#         InvoiceDate  Price  Customer ID         Country
# 1067271  2011-12-09   1.79      17581.0  United Kingdom
# 1067272  2011-12-09   1.79      17581.0  United Kingdom
# 1067273  2011-12-09   1.79      17581.0  United Kingdom
# 1067274  2011-12-09   0.83      17581.0  United Kingdom
# 1067275  2011-12-09   1.25      17581.0  United Kingdom
# ...             ...    ...          ...             ...
# 1067366  2011-12-09   2.10      12680.0          France
# 1067367  2011-12-09   4.15      12680.0          France
# 1067368  2011-12-09   4.15      12680.0          France
# 1067369  2011-12-09   4.95      12680.0          France
# 1067370  2011-12-09  18.00      12680.0          France
#
# [100 rows x 8 columns]

# %%
sales
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#         InvoiceDate  Price  Customer ID         Country
# 0        2009-12-01   6.95      13085.0  United Kingdom
# 1        2009-12-01   6.75      13085.0  United Kingdom
# 2        2009-12-01   6.75      13085.0  United Kingdom
# 3        2009-12-01   2.10      13085.0  United Kingdom
# 4        2009-12-01   1.25      13085.0  United Kingdom
# ...             ...    ...          ...             ...
# 1067366  2011-12-09   2.10      12680.0          France
# 1067367  2011-12-09   4.15      12680.0          France
# 1067368  2011-12-09   4.15      12680.0          France
# 1067369  2011-12-09   4.95      12680.0          France
# 1067370  2011-12-09  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %%
# sales['InvoiceDate']=pd.to_datetime(sales['InvoiceDate'])
# sales['Date']=pd.to_datetime(sales['InvoiceDate'].dt.date)

ans=sales[sales['Date']=='2011-06-22']
ans['Customer ID'].nunique()

# sales
# Out:
# 57

# %%
sales
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#         InvoiceDate  Price  Customer ID         Country       Date
# 0        2009-12-01   6.95      13085.0  United Kingdom 2009-12-01
# 1        2009-12-01   6.75      13085.0  United Kingdom 2009-12-01
# 2        2009-12-01   6.75      13085.0  United Kingdom 2009-12-01
# 3        2009-12-01   2.10      13085.0  United Kingdom 2009-12-01
# 4        2009-12-01   1.25      13085.0  United Kingdom 2009-12-01
# ...             ...    ...          ...             ...        ...
# 1067366  2011-12-09   2.10      12680.0          France 2011-12-09
# 1067367  2011-12-09   4.15      12680.0          France 2011-12-09
# 1067368  2011-12-09   4.15      12680.0          France 2011-12-09
# 1067369  2011-12-09   4.95      12680.0          France 2011-12-09
# 1067370  2011-12-09  18.00      12680.0          France 2011-12-09
#
# [1067371 rows x 9 columns]

# %%
# sales["total_price"] = sales["Quantity"] * sales["Price"]
# sales

sales_country = sales.groupby(["Country", "Date"])["total_price"].sum().sort_values(ascending = False)

# %%
sales_country = sales_country.reset_index()
sales_country[sales_country["Country"] == "France"]
# Out:
#      Country       Date  total_price
# 563   France 2010-08-09     12726.01
# 608   France 2011-10-28      8990.46
# 618   France 2010-05-06      8490.90
# 667   France 2011-03-31      5593.59
# 687   France 2010-11-19      5084.89
# ...      ...        ...          ...
# 3184  France 2009-12-10      -118.90
# 3190  France 2009-12-03      -143.90
# 3208  France 2010-05-28      -364.80
# 3211  France 2010-08-05      -421.40
# 3234  France 2010-09-28    -11880.84
#
# [372 rows x 3 columns]
